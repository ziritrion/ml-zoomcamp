# %% [markdown]
# [download dataset](https://www.kaggle.com/sshikamaru/car-object-detection)

# %%
import torch

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to /Users/ziri/.cache/torch/hub/master.zip
# YOLOv5 🚀 2021-11-30 torch 1.10.0 CPU
# Downloading https://github.com/ultralytics/yolov5/releases/download/v6.0/yolov5s.pt to /Users/ziri/.cache/torch/hub/ultralytics_yolov5_master/yolov5s.pt...
# 100%|██████████| 14.0M/14.0M [00:03<00:00, 4.14MB/s]
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
# Images
imgs = ['data/cars/training_images/vid_4_600.jpg']  # batch of images

# %%
# Inference
results = model(imgs)
# Out:
# /Users/ziri/anaconda3/envs/capstone/lib/python3.8/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')

# %%
# Results
results.print()
# Out:
# image 1/1: 380x676 1 car, 4 traffic lights
# Speed: 16.8ms pre-process, 213.2ms inference, 1.4ms NMS per image at shape (1, 3, 384, 640)

# %%
#results.xyxy[0]  # img1 predictions (tensor)
results.pandas().xyxy[0]  # img1 predictions (pandas)
# Out:
#          xmin        ymin        xmax        ymax  confidence  class  \
# 0  292.380829  193.928955  403.341675  230.090302    0.878298      2
# 1  594.503235  129.840439  607.721985  144.121155    0.614422      9
# 2  619.746277   88.410088  634.106140  110.498421    0.369741      9
# 3  657.899353  130.656891  669.773621  144.152939    0.357672      9
# 4  628.062927  130.348892  639.890930  143.262177    0.286768      9
#
#             name
# 0            car
# 1  traffic light
# 2  traffic light
# 3  traffic light
# 4  traffic light

# %%
from IPython.display import Image

# %%
Image('data/cars/training_images/vid_4_600.jpg')

# %%
results

# %%
results.display
# Out:
# <bound method Detections.display of <models.common.Detections object at 0x7fc16060ad90>>

# %%
results.show()
